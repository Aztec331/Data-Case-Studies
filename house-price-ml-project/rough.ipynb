# %%
import pandas as pd

data ={
    "mainroad":["yes","no","yes","no"]
}

df = pd.DataFrame(data)
# Out:
#   mainroad
# 0      yes
# 1       no
# 2      yes
# 3       no

# %%
df
# Out:
#   mainroad
# 0      yes
# 1       no
# 2      yes
# 3       no

# %%
df["mainroad"] =
